# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\moham\OneDrive\Desktop\Python\DA\cafe\dirty_cafe_sales.csv')

# Check rows x columns
#df.shape

df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#df['Item'].unique()
#df['Quantity'].unique()
#df['Price Per Unit'].unique()
#df['Total Spent'].unique()
#df['Payment Method'].unique()
#df['Location'].unique()
#df['Transaction Date'].unique()

# %%
# Replace unknown/error values

df['Item']=df['Item'].replace(['UNKNOWN','ERROR'], pd.NA)
df['Quantity']=df['Quantity'].replace(['UNKNOWN','ERROR'], pd.NA)
df['Price Per Unit']=df['Price Per Unit'].replace(['UNKNOWN','ERROR'], pd.NA)
df['Payment Method']=df['Payment Method'].replace(['UNKNOWN','ERROR'], pd.NA)
df['Location']=df['Location'].replace(['UNKNOWN','ERROR'], pd.NA)

# %%
# Check data type of each column
df.info()

# Change column data type

df['Quantity'] = df['Quantity'].astype('Int64')
df['Price Per Unit'] = pd.to_numeric(df['Price Per Unit'], errors='coerce')
df['Total Spent'] = pd.to_numeric(df['Total Spent'], errors='coerce')
df['Transaction Date']=pd.to_datetime(df['Transaction Date'], errors ='coerce')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9031 non-null   object
#  2   Quantity          9521 non-null   object
#  3   Price Per Unit    9467 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    6822 non-null   object
#  6   Location          6039 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df.head(50)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee         2             2.0          4.0
# 1     TXN_4977031      Cake         4             3.0         12.0
# 2     TXN_4271903    Cookie         4             1.0          NaN
# 3     TXN_7034554     Salad         2             5.0         10.0
# 4     TXN_3160411    Coffee         2             2.0          4.0
# 5     TXN_2602893  Smoothie         5             4.0         20.0
# 6     TXN_4433211      <NA>         3             3.0          9.0
# 7     TXN_6699534  Sandwich         4             4.0         16.0
# 8     TXN_4717867       NaN         5             3.0         15.0
# 9     TXN_2064365  Sandwich         5             4.0         20.0
# 10    TXN_2548360     Salad         5             5.0         25.0
# 11    TXN_3051279  Sandwich         2             4.0          8.0
# 12    TXN_7619095  Sandwich         2             4.0          8.0
# ...

# %%
# Convert all <NA> to NaN

df = df.fillna(value=np.nan)

# %%
# Renaming Items based on the price

#df.loc[(df['Price Per Unit'] == 1.5) & (df['Item'].isna()), 'Item'] = 'Tea'
#df.loc[(df['Price Per Unit'] == 2) & (df['Item'].isna()), 'Item'] = 'Coffee'
#df.loc[(df['Price Per Unit'] == 5) & (df['Item'].isna()), 'Item'] = 'Salad'
#df.loc[(df['Price Per Unit'] == 1) & (df['Item'].isna()), 'Item'] = 'Cookie'
df.head(40)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee         2             2.0          4.0
# 1     TXN_4977031      Cake         4             3.0         12.0
# 2     TXN_4271903    Cookie         4             1.0          NaN
# 3     TXN_7034554     Salad         2             5.0         10.0
# 4     TXN_3160411    Coffee         2             2.0          4.0
# 5     TXN_2602893  Smoothie         5             4.0         20.0
# 6     TXN_4433211       NaN         3             3.0          9.0
# 7     TXN_6699534  Sandwich         4             4.0         16.0
# 8     TXN_4717867       NaN         5             3.0         15.0
# 9     TXN_2064365  Sandwich         5             4.0         20.0
# 10    TXN_2548360     Salad         5             5.0         25.0
# 11    TXN_3051279  Sandwich         2             4.0          8.0
# 12    TXN_7619095  Sandwich         2             4.0          8.0
# ...

# %%
# Correct Total Spent column

mask = df['Total Spent'].isna() & df['Quantity'].notna()
df.loc[mask, 'Total Spent'] = df['Quantity'] * df['Price Per Unit']
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_13920\3919704368.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<FloatingArray>
# [ 4.0, 12.0,  2.0,  3.0, <NA>,  9.0,  3.0,  6.0,  3.0, 20.0,
#  ...
#  20.0,  2.0,  4.0,  3.0,  8.0, <NA>,  8.0,  6.0, 15.0,  8.0]
# Length: 482, dtype: Float64' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[mask, 'Total Spent'] = df['Quantity'] * df['Price Per Unit']

# %%
# Drop NaN, <NA>, NAT

df = df.dropna()
df = df.reset_index(drop=True)

# %%
print(df)
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee         2             2.0          4.0
# 1       TXN_4977031      Cake         4             3.0         12.0
# 2       TXN_4271903    Cookie         4             1.0          4.0
# 3       TXN_3160411    Coffee         2             2.0          4.0
# 4       TXN_2548360     Salad         5             5.0         25.0
# 5       TXN_7619095  Sandwich         2             4.0          8.0
# 6       TXN_2847255     Salad         3             5.0         15.0
# 7       TXN_6769710     Juice         2             3.0          6.0
# 8       TXN_3709394     Juice         4             3.0         12.0
# 9       TXN_3567645  Smoothie         4             4.0         16.0
# 10      TXN_5132361  Sandwich         3             4.0         12.0
# 11      TXN_9400181  Sandwich         5             4.0         20.0
# 12      TXN_5183041    Cookie         5             1.0          5.0
# ...

# %%
df.to_excel('cleaned_dirty_cafe.xlsx', index=False)
